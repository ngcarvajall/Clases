# %%
import pandas as pd
import numpy as np
### para mostrar todo la siguiente extensión
pd.set_option("display.max_columns", None)

# %%
data = {
    'Nombre': ['Ana', 'Luis', 'Sofia', 'Carlos', 'María'],
    'Edad': [23, 21, 22, 24, 20],
    'Carrera': ['Ingeniería', 'Medicina', 'Arquitectura', 'Derecho', 'Psicología'],
    'Promedio': [9.1, 8.5, 8.7, 9.0, 9.3],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla', 'Bilbao']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad       Carrera  Promedio     Ciudad
# 0     Ana    23    Ingeniería       9.1     Madrid
# 1    Luis    21      Medicina       8.5  Barcelona
# 2   Sofia    22  Arquitectura       8.7   Valencia
# 3  Carlos    24       Derecho       9.0    Sevilla
# 4   María    20    Psicología       9.3     Bilbao

# %%
df.iloc[2, 2] ### usar fila y nombre
# Out:
# 'Arquitectura'

# %%
### sacar 21 y medicina
df.iloc[1, 1:3]
# Out:
# Edad             21
# Carrera    Medicina
# Name: 1, dtype: object

# %%
### sacar promedio
df.iloc[:,3]
# Out:
# 0    9.1
# 1    8.5
# 2    8.7
# 3    9.0
# 4    9.3
# Name: Promedio, dtype: float64

# %%
### scar maria y psicologia con loc
df.loc[4,["Nombre", 'Carrera']]
# Out:
# Nombre          María
# Carrera    Psicología
# Name: 4, dtype: object

# %%
df = pd.DataFrame(data, index= ["al1", "al2", "al3", "al4", "al5"])
df
# Out:
#      Nombre  Edad       Carrera  Promedio     Ciudad
# al1     Ana    23    Ingeniería       9.1     Madrid
# al2    Luis    21      Medicina       8.5  Barcelona
# al3   Sofia    22  Arquitectura       8.7   Valencia
# al4  Carlos    24       Derecho       9.0    Sevilla
# al5   María    20    Psicología       9.3     Bilbao

# %%
df.loc["al1",["Carrera", "Promedio"]]
# Out:
# Carrera     Ingeniería
# Promedio           9.1
# Name: al1, dtype: object

# %%
df.iloc[0,2:4]
# Out:
# Carrera     Ingeniería
# Promedio           9.1
# Name: al1, dtype: object

# %%
### acceder a todas las filas de las 3 ultimas columnas
df.iloc[:, 2:5]
# Out:
#           Carrera  Promedio     Ciudad
# al1    Ingeniería       9.1     Madrid
# al2      Medicina       8.5  Barcelona
# al3  Arquitectura       8.7   Valencia
# al4       Derecho       9.0    Sevilla
# al5    Psicología       9.3     Bilbao

# %%
df.iloc[[2,4],:] ### ponemos otro corchete para sacar distintos indices separados
# Out:
#     Nombre  Edad       Carrera  Promedio    Ciudad
# al3  Sofia    22  Arquitectura       8.7  Valencia
# al5  María    20    Psicología       9.3    Bilbao

# %%
df.iloc[[2,-1],:]
# Out:
#     Nombre  Edad       Carrera  Promedio    Ciudad
# al3  Sofia    22  Arquitectura       8.7  Valencia
# al5  María    20    Psicología       9.3    Bilbao

# %%
df.iloc[::2,:]
# Out:
#     Nombre  Edad       Carrera  Promedio    Ciudad
# al1    Ana    23    Ingeniería       9.1    Madrid
# al3  Sofia    22  Arquitectura       8.7  Valencia
# al5  María    20    Psicología       9.3    Bilbao

# %%
### si esta fuera (en otra carpeta) pongo primero el nombre de la carpeta primero
df_ibm = pd.read_csv("datos_pandas/IBM_HR_Employee_Attrition_full.csv", index_col=0)
df_ibm.head()
# Out:
#    DistanceFromHome Education    EducationField  Gender MaritalStatus  Age  \
# 0                21  Bachelor             Other    Male        Single   19
# 1                25   College  Technical Degree  Female       Married   30
# 2                 1   College     Life Sciences    Male        Single   22
# 3                 4   College  Technical Degree    Male       Married   42
# 4                 2    Master     Life Sciences  Female        Single   36
#
#                              EmployeeId       DateEmployment  \
# 0  70b8db40-4f58-476f-8776-c00802b0cdb9  2000-01-13 02:53:47
# 1  0722da7a-530b-41dd-b705-c79f7627f677  2000-01-17 03:53:10
# 2  b5fed13f-7785-4daf-bb8c-1037f84e5fa7  2000-01-21 05:42:21
# 3  4b0a1169-b286-44fb-a453-b97ca934db57  2000-01-28 16:59:19
# 4  6affb754-8e52-43a7-9e97-4e373ef5fccb  2000-02-02 22:58:25
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                  14                        0                     0
# ...

# %%
df_ibm.drop(columns= ["Unnamed: 0"], inplace= True) ### el inplacer es necesario para guardar la accion
df_ibm.head()
# Out:
#                                       DistanceFromHome Education  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                21  Bachelor
# 0722da7a-530b-41dd-b705-c79f7627f677                25   College
# b5fed13f-7785-4daf-bb8c-1037f84e5fa7                 1   College
# 4b0a1169-b286-44fb-a453-b97ca934db57                 4   College
# 6affb754-8e52-43a7-9e97-4e373ef5fccb                 2    Master
#
#                                         EducationField  Gender MaritalStatus  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9             Other    Male        Single
# 0722da7a-530b-41dd-b705-c79f7627f677  Technical Degree  Female       Married
# b5fed13f-7785-4daf-bb8c-1037f84e5fa7     Life Sciences    Male        Single
# 4b0a1169-b286-44fb-a453-b97ca934db57  Technical Degree    Male       Married
# 6affb754-8e52-43a7-9e97-4e373ef5fccb     Life Sciences  Female        Single
#
#                                       Age       DateEmployment  \
# EmployeeId
# ...

# %%
df_ibm.tail(1)
# Out:
#                                       Unnamed: 0  DistanceFromHome Education  \
# EmployeeId
# 34320d20-cf61-4900-9450-c8539f23b355        1469                 5    Master
#
#                                         EducationField Gender MaritalStatus  \
# EmployeeId
# 34320d20-cf61-4900-9450-c8539f23b355  Technical Degree   Male       Married
#
#                                       Age       DateEmployment  \
# EmployeeId
# 34320d20-cf61-4900-9450-c8539f23b355   31  2022-12-30 07:15:12
#
#                                       YearsInCurrentRole  \
# EmployeeId
# 34320d20-cf61-4900-9450-c8539f23b355                   2
#
#                                       YearsSinceLastPromotion  \
# EmployeeId
# 34320d20-cf61-4900-9450-c8539f23b355                        0
#
#                                       YearsWithCurrManager  TotalWorkingYears  \
# EmployeeId
# 34320d20-cf61-4900-9450-c8539f23b355                     3                  6
#
# ...

# %%
df_ibm.sample(5)
# Out:
#                                       Unnamed: 0  DistanceFromHome Education  \
# EmployeeId
# 54ee042d-a4bf-4da9-8112-8326f744867a         580                 1   College
# 759dbe19-7efd-4d17-a162-ae0da12c6d5d        1088                 3    Master
# 2863e810-d464-4235-8643-e6ccbecb6523         751                12  Bachelor
# fb82ce53-169f-44e9-882c-4477121d84ab         156                 2   College
# 9ad7c42a-d293-4be2-8dcb-ad36d4b5e1c6         943                 2    Doctor
#
#                                      EducationField  Gender MaritalStatus  \
# EmployeeId
# 54ee042d-a4bf-4da9-8112-8326f744867a  Life Sciences  Female        Single
# 759dbe19-7efd-4d17-a162-ae0da12c6d5d          Other    Male       Married
# 2863e810-d464-4235-8643-e6ccbecb6523  Life Sciences  Female        Single
# fb82ce53-169f-44e9-882c-4477121d84ab  Life Sciences  Female      Divorced
# 9ad7c42a-d293-4be2-8dcb-ad36d4b5e1c6        Medical    Male       Married
#
# ...

# %%
df_ibm.shape
# Out:
# (1470, 35)

# %%
df_ibm.columns
# Out:
# Index(['DistanceFromHome', 'Education', 'EducationField', 'Gender',
#        'MaritalStatus', 'Age', 'DateEmployment', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'TotalWorkingYears',
#        'Over18', 'NumCompaniesWorked', 'Country', 'Sons', 'Attrition',
#        'BusinessTravel', 'DailyRate', 'Department', 'EmployeeCount',
#        'HourlyRate', 'JobLevel', 'JobRole', 'MonthlyIncome', 'MonthlyRate',
#        'OverTime', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TrainingTimesLastYear', 'EnvironmentSatisfaction', 'JobInvolvement',
#        'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction'],
#       dtype='object')

# %%
df_trabajo = df_ibm.loc[:, ['DistanceFromHome', 'Education', 'EducationField']]
df_trabajo
# Out:
#                                       DistanceFromHome Education  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                21  Bachelor
# 0722da7a-530b-41dd-b705-c79f7627f677                25   College
# b5fed13f-7785-4daf-bb8c-1037f84e5fa7                 1   College
# 4b0a1169-b286-44fb-a453-b97ca934db57                 4   College
# 6affb754-8e52-43a7-9e97-4e373ef5fccb                 2    Master
# ...                                                ...       ...
# ee51e04a-ae21-423f-91ae-bd85c93ed69d                 1   College
# 7229488d-28e5-4e95-8df4-d83c5c110722                 7   College
# d612a787-00ab-4769-a965-2b4a625b27d9                 4       NaN
# 7261478d-ea6b-4588-b803-5807218f3a00                 2       NaN
# 34320d20-cf61-4900-9450-c8539f23b355                 5    Master
#
#                                         EducationField
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9             Other
# ...

# %%
### solo columnas

df_ibm[['DistanceFromHome', 'Education', 'EducationField']] 

### tambien para filas, usamos loc e iloc
# Out:
#                                       DistanceFromHome Education  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                21  Bachelor
# 0722da7a-530b-41dd-b705-c79f7627f677                25   College
# b5fed13f-7785-4daf-bb8c-1037f84e5fa7                 1   College
# 4b0a1169-b286-44fb-a453-b97ca934db57                 4   College
# 6affb754-8e52-43a7-9e97-4e373ef5fccb                 2    Master
# ...                                                ...       ...
# ee51e04a-ae21-423f-91ae-bd85c93ed69d                 1   College
# 7229488d-28e5-4e95-8df4-d83c5c110722                 7   College
# d612a787-00ab-4769-a965-2b4a625b27d9                 4       NaN
# 7261478d-ea6b-4588-b803-5807218f3a00                 2       NaN
# 34320d20-cf61-4900-9450-c8539f23b355                 5    Master
#
#                                         EducationField
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9             Other
# ...

# %%
df_title = df_ibm[['DistanceFromHome', 'Education', 'EducationField']].head(1)
df_title.shape
df_title
# Out:
#                                       DistanceFromHome Education  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                21  Bachelor
#
#                                      EducationField
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9          Other

# %%
df_ibm.duplicated().sum() ### me dice si la fila es duplicada, el sum me dice cuantos son
# Out:
# np.int64(0)

# %%
df_ibm.head(1)
# Out:
#                                       DistanceFromHome Education  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                21  Bachelor
#
#                                      EducationField Gender MaritalStatus  Age  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9          Other   Male        Single   19
#
#                                            DateEmployment  YearsInCurrentRole  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9  2000-01-13 02:53:47                  14
#
#                                       YearsSinceLastPromotion  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                        0
#
#                                       YearsWithCurrManager  TotalWorkingYears  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                     0                  1
#
#                                      Over18  NumCompaniesWorked  Country  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9    NaN                 1.0  Austria
#
# ...

# %%
df_ibm.reset_index(inplace=True) ### para guardar el cambio
df_ibm.head(1)
# Out:
#                              EmployeeId  DistanceFromHome Education  \
# 0  70b8db40-4f58-476f-8776-c00802b0cdb9                21  Bachelor
#
#   EducationField Gender MaritalStatus  Age       DateEmployment  \
# 0          Other   Male        Single   19  2000-01-13 02:53:47
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                  14                        0                     0
#
#    TotalWorkingYears Over18  NumCompaniesWorked  Country  Sons Attrition  \
# 0                  1    NaN                 1.0  Austria     1       Yes
#
#   BusinessTravel  DailyRate Department  EmployeeCount  HourlyRate  JobLevel  \
# 0  Travel_Rarely      419.0      Sales              1          37         1
#
#                 JobRole  MonthlyIncome  MonthlyRate OverTime  \
# 0  Sales Representative           2121         9947      Yes
#
#    PercentSalaryHike  StandardHours  StockOptionLevel  TrainingTimesLastYear  \
# ...

# %%
df_ibm.set_index("nombre de la columna que pasa a indices de listas", inplace=True)

# %%
df_ibm.duplicated(subset=["EmployeeID"]) ### busca el duplicado en una columna en particular

# %%
df_ibm.drop_duplicates(keep= "last") ### elimina los duplicados y se queda con el indice lista del ultimo

# %%
df_sindupli = df_ibm.duplicated(subset=["Gender", "Education"], keep= "last") ### busca el duplicado en uestas dos columnas, quita los duplicados

# %%
df_sindupli.reset_index(drop=True, inplace= True) ### reseta el indice y elimina aquel que pasa a columna

# %%
df_ibm["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_ibm["EducationField"].unique()
# Out:
# array(['Other', 'Technical Degree', 'Life Sciences', 'Medical',
#        'Marketing', 'Human Resources'], dtype=object)

# %%
df_ibm.dtypes
# Out:
# Unnamed: 0                    int64
# DistanceFromHome              int64
# Education                    object
# EducationField               object
# Gender                       object
# MaritalStatus                object
# Age                           int64
# DateEmployment               object
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# TotalWorkingYears             int64
# Over18                       object
# NumCompaniesWorked          float64
# Country                      object
# Sons                          int64
# Attrition                    object
# BusinessTravel               object
# DailyRate                   float64
# Department                   object
# EmployeeCount                 int64
# HourlyRate                    int64
# JobLevel                      int64
# JobRole                      object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# ...

# %%
df_ibm.select_dtypes('object').columns
# Out:
# Index(['Education', 'EducationField', 'Gender', 'MaritalStatus',
#        'DateEmployment', 'Over18', 'Country', 'Attrition', 'BusinessTravel',
#        'Department', 'JobRole', 'OverTime', 'EnvironmentSatisfaction',
#        'JobInvolvement', 'JobSatisfaction', 'PerformanceRating',
#        'RelationshipSatisfaction'],
#       dtype='object')

# %%
for column in df_ibm.select_dtypes('object').column: ### me da las categorias de cada columna
    print(column)
    print(df_sindupli[column].unique)
    print
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23672\3505847826.py in ?()
# ----> 1 for column in df_ibm.select_dtypes('object').column: ### me da las categorias de cada columna
#       2     print(column)
#       3     print(df_sindupli[column].unique)
#       4     print
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
for column in df_ibm.select_dtypes('object').column: ### me da las categorias de cada columna por su tipo
    print(column)
    print(df_sindupli[column].value_counts(normalize=True,dropna=False)) ### normalize me da los porcentajes y trae los nulos
    print

# %%
df_ibm.select_dtypes(np.number).head() ### me da las variables cuyos valores sean  numeros
# Out:
#                                       Unnamed: 0  DistanceFromHome  Age  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9           0                21   19
# 0722da7a-530b-41dd-b705-c79f7627f677           1                25   30
# b5fed13f-7785-4daf-bb8c-1037f84e5fa7           2                 1   22
# 4b0a1169-b286-44fb-a453-b97ca934db57           3                 4   42
# 6affb754-8e52-43a7-9e97-4e373ef5fccb           4                 2   36
#
#                                       YearsInCurrentRole  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                  14
# 0722da7a-530b-41dd-b705-c79f7627f677                  16
# b5fed13f-7785-4daf-bb8c-1037f84e5fa7                  20
# 4b0a1169-b286-44fb-a453-b97ca934db57                  11
# 6affb754-8e52-43a7-9e97-4e373ef5fccb                  13
#
#                                       YearsSinceLastPromotion  \
# EmployeeId
# 70b8db40-4f58-476f-8776-c00802b0cdb9                        0
# ...

# %%
df_ibm.dtypes
# Out:
# Unnamed: 0                    int64
# DistanceFromHome              int64
# Education                    object
# EducationField               object
# Gender                       object
# MaritalStatus                object
# Age                           int64
# DateEmployment               object
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# TotalWorkingYears             int64
# Over18                       object
# NumCompaniesWorked          float64
# Country                      object
# Sons                          int64
# Attrition                    object
# BusinessTravel               object
# DailyRate                   float64
# Department                   object
# EmployeeCount                 int64
# HourlyRate                    int64
# JobLevel                      int64
# JobRole                      object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# ...

# %%
df_ibm.describe().T ### solo columnas numericas
# Out:
#                           count          mean          std     min      25%  \
# Unnamed: 0               1470.0    734.500000   424.496761     0.0   367.25
# DistanceFromHome         1470.0      9.192517     8.106864     1.0     2.00
# Age                      1470.0     36.923810     9.135373    18.0    30.00
# YearsInCurrentRole       1470.0      6.236054     5.366049     0.0     2.00
# YearsSinceLastPromotion  1470.0      1.042857     1.936764     0.0     0.00
# YearsWithCurrManager     1470.0      2.083673     2.617518     0.0     0.00
# TotalWorkingYears        1470.0     11.279592     7.780782     0.0     6.00
# NumCompaniesWorked       1454.0      2.676754     2.488248     0.0     1.00
# Sons                     1470.0      0.502721     0.500163     0.0     0.00
# DailyRate                1323.0    802.877551   405.960669   102.0   465.00
# EmployeeCount            1470.0      1.000000     0.000000     1.0     1.00
# ...

# %%
df_describe = df_ibm.describe(include="O").T 
df_describe.loc["Gender", "top"]
# Out:
# 'Male'

# %%
df_describe.loc["Gender", "top"] = "lolo" ### cambio el elemento

# %%
df_describe["freq2"] = df_describe["freq"] * 2 ### añado una columna

# %%
df_describe
# Out:
#                          count unique                     top  freq freq2
# Education                 1260      5                Bachelor   479   958
# EducationField            1470      6           Life Sciences   606  1212
# Gender                    1470      2                    Male   882  1764
# MaritalStatus             1470      3                 Married   673  1346
# DateEmployment            1470   1467     2001-12-21 11:10:19     2     4
# Over18                    1161      1                       Y  1161  2322
# Country                   1470     70                 Noruega    46    92
# Attrition                 1470      2                      No  1233  2466
# BusinessTravel            1323      3           Travel_Rarely   941  1882
# Department                1470      3  Research & Development   961  1922
# JobRole                   1470      9         Sales Executive   326   652
# OverTime                  1470      2                      No  1054  2108
# ...

# %%
np.round(df_ibm.notnull().sum() / df_ibm.shape[0] * 100)
# Out:
# Unnamed: 0                  100.0
# DistanceFromHome            100.0
# Education                    86.0
# EducationField              100.0
# Gender                      100.0
# MaritalStatus               100.0
# Age                         100.0
# DateEmployment              100.0
# YearsInCurrentRole          100.0
# YearsSinceLastPromotion     100.0
# YearsWithCurrManager        100.0
# TotalWorkingYears           100.0
# Over18                       79.0
# NumCompaniesWorked           99.0
# Country                     100.0
# Sons                        100.0
# Attrition                   100.0
# BusinessTravel               90.0
# DailyRate                    90.0
# Department                  100.0
# EmployeeCount               100.0
# HourlyRate                  100.0
# JobLevel                    100.0
# JobRole                     100.0
# MonthlyIncome               100.0
# MonthlyRate                 100.0
# OverTime                    100.0
# ...

# %%
df_ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1470 entries, 70b8db40-4f58-476f-8776-c00802b0cdb9 to 34320d20-cf61-4900-9450-c8539f23b355
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1470 non-null   int64
#  1   DistanceFromHome          1470 non-null   int64
#  2   Education                 1260 non-null   object
#  3   EducationField            1470 non-null   object
#  4   Gender                    1470 non-null   object
#  5   MaritalStatus             1470 non-null   object
#  6   Age                       1470 non-null   int64
#  7   DateEmployment            1470 non-null   object
#  8   YearsInCurrentRole        1470 non-null   int64
#  9   YearsSinceLastPromotion   1470 non-null   int64
#  10  YearsWithCurrManager      1470 non-null   int64
#  11  TotalWorkingYears         1470 non-null   int64
# ...

# %%
df_describe.to_csv('datos_pandas/chapuza1.csv')

# %%
productos = {
    'id_producto': [1, 2, 3, 4],
    'nombre': ['Producto A', 'Producto B', 'Producto C', 'Producto D'],
    'precio': [100, 200, 150, 300]
}
inventario = {
    'id_producto': [1, 2, 3, 5],
    'cantidad': [50, 20, 30, 15]
}

proveedores = {
    'id_proveedor': [101, 102, 103],
    'id_producto': [1, 3, 4],
    'nombre_proveedor': ['Proveedor X', 'Proveedor Y', 'Proveedor Z']
}

productos2 = {
    'id_producto': [4,5],
    'nombre': ['Producto E', 'Producto F'],
    'precio': [1000, 2000]
}

df2 = pd.DataFrame(productos2)
df_productos = pd.DataFrame(productos)
df_inventarios = pd.DataFrame(inventario)
df_proveedores = pd.DataFrame(proveedores)

# %%
df_productos
# Out:
#    id_producto      nombre  precio
# 0            1  Producto A     100
# 1            2  Producto B     200
# 2            3  Producto C     150
# 3            4  Producto D     300

# %%
df2
# Out:
#    id_producto      nombre  precio
# 0            4  Producto E    1000
# 1            5  Producto F    2000

# %%
df_concat = pd.concat([df_productos,df2]) ### los une pero uno debajo del otro
df_concat
# Out:
#    id_producto      nombre  precio
# 0            1  Producto A     100
# 1            2  Producto B     200
# 2            3  Producto C     150
# 3            4  Producto D     300
# 0            4  Producto E    1000
# 1            5  Producto F    2000

# %%
df_concat = pd.concat([df_productos,df2]).reset_index(drop= True) ### une y organiza nuevamente los indiceselimiando la columna
df_concat ### union
# Out:
#    id_producto      nombre  precio
# 0            1  Producto A     100
# 1            2  Producto B     200
# 2            3  Producto C     150
# 3            4  Producto D     300
# 4            4  Producto E    1000
# 5            5  Producto F    2000

# %%
df_inventarios
# Out:
#    id_producto  cantidad
# 0            1        50
# 1            2        20
# 2            3        30
# 3            5        15

# %%
df_proveedores
# Out:
#    id_proveedor  id_producto nombre_proveedor
# 0           101            1      Proveedor X
# 1           102            3      Proveedor Y
# 2           103            4      Proveedor Z

# %%
productos2 = {
    'id_producto': [4,5],
    'nombre': ['Producto E', 'Producto F'],
    'precio': [1000, 2000]
}

df2 = pd.DataFrame(productos2)

# %%
df_concat.merge(df_inventarios, on = "id_producto") ### union nombre de izq con nombre de derecha
# Out:
#    id_producto      nombre  precio  cantidad
# 0            1  Producto A     100        50
# 1            2  Producto B     200        20
# 2            3  Producto C     150        30
# 3            5  Producto F    2000        15

# %%
df_concat.merge(df_inventarios, on = "id_producto", how= 'left') ### el nan surge porque no tienen cantidad, ya que solo se busca el match desde el inner join
# Out:
#    id_producto      nombre  precio  cantidad
# 0            1  Producto A     100      50.0
# 1            2  Producto B     200      20.0
# 2            3  Producto C     150      30.0
# 3            4  Producto D     300       NaN
# 4            4  Producto E    1000       NaN
# 5            5  Producto F    2000      15.0

# %%
df_concat.merge(df_inventarios, right_on = "id_producto", left_on= 'id_prod') ### esto es si tuviese dos nombres distintos

### de esta forma uno info de distintos lugares y así vamos buscando donde se unen
# si tengo dos columnas, uso el merge

# %%
df_inventarios.join(df_concat, on ="id_producto", how= "left")
### toma el indice de de_inventario, con la columna  id_producto de df_concat
### solo uso hoy si tengo info en indice y columna

# %%
df_productos
# Out:
#    id_producto      nombre  precio
# 0            1  Producto A     100
# 1            2  Producto B     200
# 2            3  Producto C     150
# 3            4  Producto D     300

# %%
df_inventarios
# Out:
#    id_producto  cantidad
# 0            1        50
# 1            2        20
# 2            3        30
# 3            5        15

# %%
# !pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         2.4.1
# colorama          0.4.6
# comm              0.2.2
# debugpy           1.8.2
# decorator         5.1.1
# executing         2.0.1
# ipykernel         6.29.5
# ipython           8.26.0
# jedi              0.19.1
# jupyter_client    8.6.2
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# numpy             2.1.2
# packaging         24.1
# pandas            2.2.3
# parso             0.8.4
# pip               24.2
# platformdirs      4.2.2
# prompt_toolkit    3.0.47
# psutil            6.0.0
# pure-eval         0.2.2
# Pygments          2.18.0
# python-dateutil   2.9.0.post0
# pytz              2024.2
# pywin32           306
# pyzmq             26.0.3
# six               1.16.0
# stack-data        0.6.3
# tornado           6.4.1
# traitlets         5.14.3
# typing_extensions 4.12.2
# tzdata            2024.2
# wcwidth           0.2.13

# %%
df_prueba = pd.read_csv("datos_pandas/IBM_HR_Employee_Attrition_full.csv", index_col=0)
df_prueba
# Out:
#       DistanceFromHome Education    EducationField  Gender MaritalStatus  Age  \
# 0                   21  Bachelor             Other    Male        Single   19
# 1                   25   College  Technical Degree  Female       Married   30
# 2                    1   College     Life Sciences    Male        Single   22
# 3                    4   College  Technical Degree    Male       Married   42
# 4                    2    Master     Life Sciences  Female        Single   36
# ...                ...       ...               ...     ...           ...  ...
# 1465                 1   College           Medical  Female        Single   30
# 1466                 7   College           Medical    Male       Married   39
# 1467                 4       NaN           Medical  Female       Married   24
# 1468                 2       NaN   Human Resources  Female       Married   25
# 1469                 5    Master  Technical Degree    Male       Married   31
#
# ...

# %%
condicion_ex = df_prueba['Attrition'] == 'Yes'
condicion_ex
df_yes = df_ibm[condicion_ex]
df_yes.head(1)
# Out:
#    DistanceFromHome Education EducationField Gender MaritalStatus  Age  \
# 0                21  Bachelor          Other   Male        Single   19
#
#                              EmployeeId       DateEmployment  \
# 0  70b8db40-4f58-476f-8776-c00802b0cdb9  2000-01-13 02:53:47
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                  14                        0                     0
#
#    TotalWorkingYears Over18  NumCompaniesWorked  Country  Sons Attrition  \
# 0                  1    NaN                 1.0  Austria     1       Yes
#
#   BusinessTravel  DailyRate Department  EmployeeCount  HourlyRate  JobLevel  \
# 0  Travel_Rarely      419.0      Sales              1          37         1
#
#                 JobRole  MonthlyIncome  MonthlyRate OverTime  \
# 0  Sales Representative           2121         9947      Yes
#
#    PercentSalaryHike  StandardHours  StockOptionLevel  TrainingTimesLastYear  \
# ...

# %%
df_yes('Attrition').shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 df_yes('Attrition').shape
#
# TypeError: 'DataFrame' object is not callable

# %%
condicion_income = df_ibm['MonthlyIncome'] > 15000
df_income = df[condicion_income]
df_income.head(1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23672\3714465325.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_income = df[condicion_income]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[143], line 2
#       1 condicion_income = df_ibm['MonthlyIncome'] > 15000
# ----> 2 df_income = df[condicion_income]
#       3 df_income.head(1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
# ...

# %%
# %%time

condicion_casado = df_ibm['MaritalStatus'] == 'Married' 
condicion_income = df_ibm['MonthlyIncome'] > 15000

df_income_casados = df[condicion_casado & condicion_income]
df_income_casados.head(2)
# Out:
# <timed exec>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# File <timed exec>:4
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %%
df_income_casados2 = df[condicion_casado] [condicion_income]

# %%
df_income_casados.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 df_income_casados.shape
#
# NameError: name 'df_income_casados' is not defined

# %%
df_income_casados2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 df_income_casados2.shape
#
# NameError: name 'df_income_casados2' is not defined

# %%
df_income_casados.describe().T

# %%
df_incomesuperior_casados = df[condicion_casados | condicion_income]

# %%
df[(df['MaritalStatus'] == 'Married') & (df['MonthlyIncome'] > 15000)]

### almacenar las condiciones en variables

# %%
df['Education'].unique()

# %%
condicion_bach = df['Education'] == 'Bachelor'
condicion_doctor = df['Education'] == 'Doctor'
df[condicion_bach |condicion_doctor].head(2)

# %%
### podemos agregar otra lista y luego llamar ambas condiciones
### se usa el .isin para buscar varias condiciones con variables categoricas
lista_education = ['Bachelor', 'Doctor']
dfeducation = df[df['Education'].isin(lista_education)]

# %%
lista_education1 = ['Bachelor', 'Doctor', 'Male']
condicion_edu = df['Eduacation'].isin(lista_education1)
dfeducation = df[df['Education'].isin(lista_education1)]

# %%
filtro_edad = [19,21,32]
df_edad = df[df['Age'].isin(filtro_edad)]
df_edad.head()

# %%
df_edad['Age'].unique()
